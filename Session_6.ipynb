# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\amol\Hydrabad\Naresh_IT\Data_Science&Ai_by_OmkarSir\Classes\EDA\DataFrame\Visadataset.csv"
df_visa=pd.read_csv(file_path)
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=df_visa.select_dtypes(include ='object').columns
num=df_visa.select_dtypes(exclude='object').columns

# %%
df_visa[['continent','case_status']]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
df_visa['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
df_visa['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
- How many members are certified from Asia

- How many members are denied from Asia
# Out:
#   Cell In[7], line 1
#     - How many members are certified from Asia
#           ^
# SyntaxError: invalid syntax

# %%
# count=0
# for i in range(len(df_visa['continent'])):
#     if df_visa['continent']=='Asia' and df_visa['case_status']=='Certified ':
#         count=count+1
# print(count)

# %%
con1=df_visa['continent']=='Asia'
con2=df_visa['case_status']=='Certified'
con=con1&con2
deni_con=con1&con3
append here len(df_visa[cer])
len(df_visa[con])
# Out:
#   Cell In[8], line 5
#     append here len(df_visa[cer])
#            ^
# SyntaxError: invalid syntax

# %%
con1=df_visa['continent']=='Asia'
con2=df_visa['case_status']=='Certified'
con=con1&con2
len(df_visa[con])
# Out:
# 11012

# %%
con1=df_visa['continent']=='Asia'
con2=df_visa['case_status']=='Certified'
con3=df_visa['case_status']=='Denied'
certi_con=con1&con2
deni_con=con1&con3
len(df_visa[certi_con]),len(df_visa[deni_con])
# Out:
# (11012, 5849)

# %%
labels=df_visa['continent'].unique()
certified,denied=[],[]
for i in labels:
    
    con1=df_visa['continent']==i
    con2=df_visa['case_status']=='Certified'
    con3=df_visa['case_status']=='Denied'
    certi_con=con1&con2
    deni_con=con1&con3
    certified.append(len(df_visa[certi_con]))
    denied.append(len(df_visa[deni_con]))

# %%
case_labels=sorted(df_visa['case_status'].unique())

# %%
pd.DataFrame(zip(certified,denied),
             index=labels,
             columns=case_labels)
# Out:
#                Certified  Denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# **crosstab**

# %%
id_col=df_visa['continent']
col=df_visa['case_status']
r1=pd.crosstab(id_col,col)
r1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
id_col=df_visa['continent']
col=df_visa['case_status']
r11=pd.crosstab(col,id_col)
r11
# Out:
# continent    Africa   Asia  Europe  North America  Oceania  South America
# case_status
# Certified       397  11012    2957           2037      122            493
# Denied          154   5849     775           1255       70            359

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
sns.countplot(data=df_visa,x='continent',
             hue='case_status')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
sns.countplot(data=df_visa,x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
sns.countplot(data=df_visa,x='continent',
             hue='case_status',
             palette='Set2',
             width=0.6)
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
# scatter plot
# correlation
# heatmaps
# streamlit rag
# llma access api key

# %%
id_col=df_visa['continent']
col=df_visa['case_status']
r11=pd.crosstab(col,id_col)
r11
# Out:
# continent    Africa   Asia  Europe  North America  Oceania  South America
# case_status
# Certified       397  11012    2957           2037      122            493
# Denied          154   5849     775           1255       70            359

# %%
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
col1=df_visa['continent']
col2=df_visa['education_of_employee']
col3=df_visa['case_status']
id_col=col1
cols=[col2,col3]
pd.crosstab(col1,cols)
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
col1=df_visa['continent']
col2=df_visa['education_of_employee']
col3=df_visa['case_status']
id_col=col2
cols=[col1,col3]
r2=pd.crosstab(id_col,cols)
r2
# Out:
# continent                Africa             Asia           Europe         \
# case_status           Certified Denied Certified Denied Certified Denied
# education_of_employee
# Bachelor's                   81     62      4407   2761      1040    259
# Doctorate                    43     11       780    143       788     58
# High School                  23     43       676   1614       162    328
# Master's                    250     38      5149   1331       967    130
#
# continent             North America          Oceania        South America  \
# case_status               Certified Denied Certified Denied     Certified
# education_of_employee
# Bachelor's                      641    584        38     28           160
# Doctorate                       207     51        19      3            75
# High School                     210    191        19     17            74
# Master's                        979    429        46     22           184
#
# continent
# ...

# %%
r2.plot(kind='bar')
# Out:
# <Axes: xlabel='education_of_employee'>

# %% [markdown]
# **Scatter plots**

# %% [markdown]
# - bar chart: frequency table
#
# - pie chart : relative frequncy table
#
# - histogram  : frequency distribution plot
#
# - box plot : Outliner analysis
#
# - scatterplot  : Relation between two Number columns

# %%
x=list(range(1,11))
y=list(range(1,11))
plt.scatter(x,y)
plt.plot(x,y)

# %%
x=list(range(-4,5))
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)

# %%
col1= df_visa['prevailing_wage']
col2=df_visa['no_of_employees']
col3=df_visa['yr_of_estab']
plt.figure(figsize=(14,5))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)

# %%
df_visa.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# **Heatmap**

# %%
corr=df_visa.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# step-1 : wine quality dataset
# step-2: apply the correlation : 12*12=144 vlues
# step-3: By seeing this 144 human eyes can't identiy which hiegh and which law relation so draw heath
# step-4: get the column pair hier post,high neg,no relation
#strep-5: Draw the scatter plot

# %%
file_path=r"C:\Users\amol\Hydrabad\Naresh_IT\Data_Science&Ai_by_OmkarSir\Classes\EDA\DataFrame\winequality_red.csv"
wine_df=pd.read_csv(file_path)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(wine_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
col1=wine_df['fixed acidity']
col2=wine_df['citric acid']
col3=wine_df['pH']
col4=wine_df['alcohol']
plt.figure(figsize=(14,5))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)
