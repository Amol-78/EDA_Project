# %% [markdown]
# - Before model Devlopement
#
# - WE will do EDA : Exploratry data analysis
#
#     - Feature(columns) analysis
#
#         - Csategorucal , Numerical  ,Outier analysis ,Bivariate Multivariate
#
#         - we will get the insights
#
#    - Feature Engineering
#
#        - we will modify the data
#
#       - Models devloped by maths
#
#       - Encoding : Convert categorical data to Numerical Variables
#
#       - Scaling : All the numerical columns makes under one scale
#
#       - Transformation :  All the maths devloped by assumption data follows normal distributionj
#
#           - Convert skewed distribution to normal
#
#
#
#  - Future Salection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as san

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
path='Visadataset.csv'
visa_df=pd.read_csv(path)

# %%
cat = visa_df.select_dtypes

# %% [markdown]
# **map method**
#
# - create a dictionry lebales as keys number a vsalues
#
# - in  python strt with 0
#
# - case status has two labels we need two 0 and 1
#
#      - certified 0
#
#      - denied 1

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
visa_df['case_status'].nunique()
# Out:
# 2

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# idea
# how many lables that many numbers start 0 end with len 
# empty dictionry
d={}
d['Apple']=20
d
# Out:
# {'Apple': 20}

# %%
d={}
d['Certified']=0
d['Denied']=1
d
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
d={}
lables=visa_df['continent'].unique()
for i in range(visa_df['continent'].nunique()):
    d[lables[i]] = i
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
visa_df=pd.read_csv(path)
d={}
label=visa_df['case_status'].unique()
for i in range(len(label)):
    d[label[i]] = i
print(d)
visa_df['case_status']=visa_df['case_status'].map(d)
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
visa_df=pd.read_csv(path)
label=visa_df['case_status'].unique()
d={label[i]:i for i in range(len(label))}
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df=pd.read_csv(path)
for i in cat[1:]:
    label=visa_df[i].unique()
    d={label[i]:i for i in range(len(label))}
    visa_df[i]=visa_df[i].map(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 visa_df=pd.read_csv(path)
# ----> 2 for i in cat[1:]:
#       3     label=visa_df[i].unique()
#       4     d={label[i]:i for i in range(len(label))}
#
# TypeError: 'method' object is not subscriptable

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **LabelEncode**
#
# - Sickit-learn(skelearn)
#
# - sklearn library is a heart of machine learning in python
#
# - MLlib is heart of machine learning in pyspark
#
# - sklearn
#
#       - preprocess
#
#
#               - Label Encoder(Method)
#
#   - fit : calcuate something
#
#   - fit_transform : we are modify the values because o calculate one

# %%
visa_df=pd.read_csv(path)

# %%
from sklearn.preprocessing import LabelEncoder # read the method
le= LabelEncoder()  # save the method
le.fit_transform(visa_df['case_status']) # apply the fit transform
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# **OneHotEncoder**
#
# |Denied|1|0|
#
# certified   0       1
#
# certified   0       1
#
# denied      1       0

# %% [markdown]
# - oneHotEncoder creates nwe columnes that equal to number of unique labels
#
# - one Distadvantages is data dimensions will be icreased
#
# - more dimensions leads to more processing time leads to bigger inra memory
#
# - this is called as **curse of dimensionality**
#
# - Advantage
#
#      - generally ml algorithm excpects no correlation between input columns
#
#      - when one colum value availbel and at a same time another columns not availabel means
#
#      - bothe are endependet each other

# %%
cat[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat[4]
# Out:
# 'requires_job_training'

# %%
pd.get_dummies(visa_df,columns=cat[1:],
              dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
- if data is on ordinal go with labelEncoder

- if data is nominal go with on
